# %%
import pandas as pd

# Note: 2011-2013 represent top 100 billed services. 2014-2017 represent all billed services
data_2011= "data_cms_gov/Medicare_Provider_Charge_Inpatient_DRG100_FY2011.csv"
data_2012= "data_cms_gov/Medicare_Provider_Charge_Inpatient_DRG100_FY2012.csv"
data_2013= "data_cms_gov/Medicare_Provider_Charge_Inpatient_DRG100_FY2013.csv"
data_2014= "data_cms_gov/Medicare_Provider_Charge_Inpatient_DRGALL_FY2014.csv"
data_2015= "data_cms_gov/Medicare_Provider_Charge_Inpatient_DRGALL_FY2015.csv"
data_2016= "data_cms_gov/Medicare_Provider_Charge_Inpatient_DRGALL_FY2016.csv"
data_2017= "data_cms_gov/Medicare_Provider_Charge_Inpatient_DRGALL_FY2017.csv"

# Read School and Student Data File and store into Pandas Data Frames
data_2011_df = pd.read_csv(data_2011, low_memory=False)
data_2012_df = pd.read_csv(data_2012, low_memory=False)
data_2013_df = pd.read_csv(data_2013, low_memory=False)
data_2014_df = pd.read_csv(data_2014, low_memory=False)
data_2015_df = pd.read_csv(data_2015, low_memory=False)
data_2016_df = pd.read_csv(data_2016, low_memory=False)
data_2017_df = pd.read_csv(data_2017, low_memory=False)

data_2011_df.head()
# Out:
#                              DRG Definition  Provider Id  \
# 0  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        10001
# 1  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        10005
# 2  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        10006
# 3  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        10011
# 4  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        10016
#
#                       Provider Name     Provider Street Address Provider City  \
# 0  SOUTHEAST ALABAMA MEDICAL CENTER      1108 ROSS CLARK CIRCLE        DOTHAN
# 1     MARSHALL MEDICAL CENTER SOUTH  2505 U S HIGHWAY 431 NORTH          BOAZ
# 2    ELIZA COFFEE MEMORIAL HOSPITAL          205 MARENGO STREET      FLORENCE
# 3                 ST VINCENT'S EAST  50 MEDICAL PARK EAST DRIVE    BIRMINGHAM
# 4     SHELBY BAPTIST MEDICAL CENTER     1000 FIRST STREET NORTH     ALABASTER
#
#   Provider State  Provider Zip Code  \
# 0             AL              36301
# 1             AL              35957
# 2             AL              35631
# ...

# %%
data_2016_df.head()

data_2016_df.iloc[111178]

#data_2016_df.dtypes
# Out:
# DRG Definition                                392 - ESOPHAGITIS, GASTROENT & MISC DIGEST DIS...
# Provider Id                                                                              100007
# Provider Name                                                                  FLORIDA HOSPITAL
# Provider Street Address                                                        601 E ROLLINS ST
# Provider City                                                                           ORLANDO
# Provider State                                                                               FL
# Provider Zip Code                                                                         32803
# Hospital Referral Region (HRR) Description                                         FL - Orlando
# Total Discharges                                                                          1,134
# Average Covered Charges                                                              $31,757.38
# ...

# %%
#convert to NaN
#data_2016_df["Total Discharges"] = pd.to_numeric(data_2016_df["Total Discharges"], errors='coerce')

#data_2016_df.drop(data_2016_df.index[111178])

#clean_data_2016_df = data_2016_df.at['111178', 'Total Discharges'] = 1134


unclean_2016_df = data_2016_df[data_2016_df["Total Discharges"].isnull()]
unclean_2016_df.count()
#41 rows to drop

#drop rows with NaN
data_2016_df.count()
cleaned_2016_df = data_2016_df.dropna()
cleaned_2016_df
# Out:
#                                            DRG Definition  Provider Id  \
# 0       001 - HEART TRANSPLANT OR IMPLANT OF HEART ASS...        10033
# 1       001 - HEART TRANSPLANT OR IMPLANT OF HEART ASS...        30103
# 2       001 - HEART TRANSPLANT OR IMPLANT OF HEART ASS...        40114
# 3       001 - HEART TRANSPLANT OR IMPLANT OF HEART ASS...        50025
# 4       001 - HEART TRANSPLANT OR IMPLANT OF HEART ASS...        50100
# ...                                                   ...          ...
# 197278  988 - NON-EXTENSIVE O.R. PROC UNRELATED TO PRI...       520177
# 197279  989 - NON-EXTENSIVE O.R. PROC UNRELATED TO PRI...       170104
# 197280  989 - NON-EXTENSIVE O.R. PROC UNRELATED TO PRI...       180088
# 197281  989 - NON-EXTENSIVE O.R. PROC UNRELATED TO PRI...       220071
# 197282  989 - NON-EXTENSIVE O.R. PROC UNRELATED TO PRI...       360180
#
#                                             Provider Name  \
# ...

# %%
zip_code = 60035
a = str(zip_code)
b= zip_code.astype(str)
final_zip = b[:3]

# final = string.split(";")[-1]
final_zip
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-05376f12b8d8> in <module>
#       1 zip_code = 60035
#       2 a = str(zip_code)
# ----> 3 b= zip_code.astype(str)
#       4 final_zip = b[:3]
#       5
#
# AttributeError: 'int' object has no attribute 'astype'

# %%
import pandas as pd
df = pd.DataFrame({"A" : ["60035", "89002", "39777"]}) 

df["B"] = ''
n = 0
for i, row in df.iterrows():
    df.iloc[n,-1]= df.iloc[n,0][:3]
    n +=1

df.head()
# Out:
#        A    B
# 0  60035  600
# 1  89002  890
# 2  39777  397

# %%
import pandas as pd
df = pd.DataFrame({"A" : [60035, 89002, 39777]}) 


for i, row in df.iterrows():
    row['B'] = df.iloc[row["A"]][0:3]



# def greet(name):
#     """
#     This function greets to
#     the person passed in as
#     a parameter
#     """
#     name = name[:3]
#     print("Hello, " + name + ". Good morning!")

# greet(name)

# #df['A']=df.A.map(lambda x: x*100)
# # df['A']=df.A.map(lambda x: [:3])


# # df

# # for i in df.index:
# #     df.at[i[0:3], "A"]
    
# # df

# # for i, row in df.iterrows():
# #     row['A'] = df.at[i[0:3], "A"]
    
# # for i, row in df.iterrows():
# #     ifor_val = df.at[i[0:3], "A"]
# #     df.at[i,'A'] = ifor_val
    
    
# # for i in df.index:
# #         df.at[i, 'A'] = df.at[i[0:3], "A"]
        
        
# # for i, row in df.iterrows():
# #     row['A'] = df.at[i[0:3], "A"]
# #     df.ix[i]['A'] = x
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-6bce6b44fbec> in <module>
#       2 df = pd.DataFrame({"A" : [60035, 89002, 39777]})
#       3
# ----> 4 s = Substr(s, beginning, LENGTH)
#       5
#       6 for i, row in df.iterrows():
#
# NameError: name 'Substr' is not defined

# %%
#add year column
# data_2011_df['Payment Year'] = 2011
# data_2012_df['Payment Year'] = 2012
# data_2013_df['Payment Year'] = 2013
# data_2014_df['Payment Year'] = 2014
# data_2015_df['Payment Year'] = 2015
# data_2016_df['Payment Year'] = 2016
# data_2017_df['Payment Year'] = 2017
# data_2017_df

#rename column
# data_2011_year_df=data_2011_df.rename(columns={"Year": "Payment Year"})
# data_2012_year_df=data_2012_df.rename(columns={"Year": "Payment Year"})
# data_2013_year_df=data_2013_df.rename(columns={"Year": "Payment Year"})
# data_2014_year_df=data_2014_df.rename(columns={"Year": "Payment Year"})
# data_2015_year_df=data_2015_df.rename(columns={"Year": "Payment Year"})
# data_2016_year_df=data_2016_df.rename(columns={"Year": "Payment Year"})
# data_2017_year_df=data_2017_df.rename(columns={"Year": "Payment Year"})

data_2017_year_df
# Out:
#                                            DRG Definition  Provider Id  \
# 0       023 - CRANIOTOMY W MAJOR DEVICE IMPLANT OR ACU...        10001
# 1       025 - CRANIOTOMY & ENDOVASCULAR INTRACRANIAL P...        10001
# 2       027 - CRANIOTOMY & ENDOVASCULAR INTRACRANIAL P...        10001
# 3                     037 - EXTRACRANIAL PROCEDURES W MCC        10001
# 4                      038 - EXTRACRANIAL PROCEDURES W CC        10001
# ...                                                   ...          ...
# 196320                           683 - RENAL FAILURE W CC       670120
# 196321    690 - KIDNEY & URINARY TRACT INFECTIONS W/O MCC       670120
# 196322  871 - SEPTICEMIA OR SEVERE SEPSIS W/O MV >96 H...       670120
# 196323  470 - MAJOR JOINT REPLACEMENT OR REATTACHMENT ...       670122
# 196324  871 - SEPTICEMIA OR SEVERE SEPSIS W/O MV >96 H...       670122
#
#                                            Provider Name  \
# ...
